# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import tree
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

# %%
from IPython.display import HTML
style  = "<style>svg{width:80% !important; height:70% !important;}</style>"
HTML(style)
# Out:
# <style>svg{width:80% !important; height:70% !important;}</style>

# %%
train_iris_data = pd.read_csv('C:/Users/Asus/Desktop/NEURAL_NETWORKS/Specification/SolvingTrees/train_iris.csv',index_col=0)

# %%
test_iris_data = pd.read_csv('C:/Users/Asus/Desktop/NEURAL_NETWORKS/Specification/SolvingTrees/test_iris.csv',index_col=0)

# %%
train_iris_data
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 130           7.4          2.8           6.1          1.9        2
# 7             5.0          3.4           1.5          0.2        0
# 11            4.8          3.4           1.6          0.2        0
# 142           5.8          2.7           5.1          1.9        2
# 109           7.2          3.6           6.1          2.5        2
# ..            ...          ...           ...          ...      ...
# 147           6.5          3.0           5.2          2.0        2
# 124           6.7          3.3           5.7          2.1        2
# 123           6.3          2.7           4.9          1.8        2
# 146           6.3          2.5           5.0          1.9        2
# 68            6.2          2.2           4.5          1.5        1
#
# [100 rows x 5 columns]

# %%
test_iris_data
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 114           5.8          2.8           5.1          2.4        2
# 70            5.9          3.2           4.8          1.8        1
# 138           6.0          3.0           4.8          1.8        2
# 59            5.2          2.7           3.9          1.4        1
# 44            5.1          3.8           1.9          0.4        0
# 125           7.2          3.2           6.0          1.8        2
# 36            5.5          3.5           1.3          0.2        0
# 141           6.9          3.1           5.1          2.3        2
# 12            4.8          3.0           1.4          0.1        0
# 63            6.1          2.9           4.7          1.4        1
# 106           4.9          2.5           4.5          1.7        2
# 96            5.7          2.9           4.2          1.3        1
# 103           6.3          2.9           5.6          1.8        2
# ...

# %%
train_iris_data.isnull().sum()
# Out:
# Unnamed: 0      0
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# species         0
# dtype: int64

# %%
X_train = train_iris_data.drop('species', axis = 1)
y_train = train_iris_data.species

# %%
np.random.seed(0)
clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 10)

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
graph = Source(tree.export_graphviz(
    clf, out_file = None,
    feature_names = list(X), class_names = ['0','1', '2'],
    filled = True))
display(SVG(graph.pipe(format = 'svg')))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.33, random_state = 42)

# %%
X_train
# Out:
#     sepal length  sepal width  petal length  petal width
# 28           4.9          3.1           1.5          0.1
# 93           4.9          2.4           3.3          1.0
# 5            4.4          3.2           1.3          0.2
# 66           6.1          3.0           4.6          1.4
# 65           7.3          2.9           6.3          1.8
# ..           ...          ...           ...          ...
# 60           5.1          3.7           1.5          0.4
# 71           5.6          2.9           3.6          1.3
# 14           5.5          2.4           3.8          1.1
# 92           4.8          3.4           1.9          0.2
# 51           5.1          3.8           1.6          0.2
#
# [67 rows x 4 columns]

# %%
X_test
# Out:
#     sepal length  sepal width  petal length  petal width
# 0            5.8          2.8           5.1          2.4
# 1            5.9          3.2           4.8          1.8
# 2            6.0          3.0           4.8          1.8
# 3            5.2          2.7           3.9          1.4
# 4            5.1          3.8           1.9          0.4
# 5            7.2          3.2           6.0          1.8
# 6            5.5          3.5           1.3          0.2
# 7            6.9          3.1           5.1          2.3
# 8            4.8          3.0           1.4          0.1
# 9            6.1          2.9           4.7          1.4
# 10           4.9          2.5           4.5          1.7
# 11           5.7          2.9           4.2          1.3
# 12           6.3          2.9           5.6          1.8
# 13           4.6          3.6           1.0          0.2
# 14           5.0          3.4           1.6          0.4
# ...

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
clf.score(X_test, y_test)
# Out:
# 0.92

# %%
scores_data = pd.DataFrame()

# %%
max_depth_values = range(1,100)
np.random.seed(0)
for max_depth in max_depth_values:
    clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = max_depth)
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train,y_train)
    test_score = clf.score(X_test, y_test)
    temp_score_data = pd.DataFrame({'max_depth' : [max_depth],
                                   'train_score' : [train_score],
                                   'test_score' : [test_score]})
    scores_data = scores_data.append(temp_score_data)

# %%
scores_data
# Out:
#     max_depth  train_score  test_score
# 0           1     0.716418    0.666667
# 0           2     1.000000    0.909091
# 0           3     1.000000    0.909091
# 0           4     1.000000    0.909091
# 0           5     1.000000    0.909091
# ..        ...          ...         ...
# 0          95     1.000000    0.909091
# 0          96     1.000000    0.909091
# 0          97     1.000000    0.909091
# 0          98     1.000000    0.909091
# 0          99     1.000000    0.909091
#
# [99 rows x 3 columns]

# %%
scores_data.shape
# Out:
# (99, 3)

# %%
scores_data_long = scores_data

# %%
scores_data_long = pd.melt(scores_data, id_vars = ['max_depth'], 
                          value_vars = ['train_score', 'test_score'],
                          var_name = 'set_type', value_name = 'score')

# %%
scores_data_long
# Out:
#      max_depth     set_type     score
# 0            1  train_score  0.716418
# 1            2  train_score  1.000000
# 2            3  train_score  1.000000
# 3            4  train_score  1.000000
# 4            5  train_score  1.000000
# ..         ...          ...       ...
# 193         95   test_score  0.920000
# 194         96   test_score  0.920000
# 195         97   test_score  0.920000
# 196         98   test_score  0.920000
# 197         99   test_score  0.920000
#
# [198 rows x 3 columns]

# %%
sns.lineplot(x = 'max_depth', y = 'score', hue = 'set_type', data = scores_data_long)

# %%
X_test = test_iris_data.drop('species', axis = 1)
y_test = test_iris_data.species

clf.score(X_test, y_test)
# Out:
# 0.92

# %%
X_test
# Out:
#      sepal length  sepal width  petal length  petal width
# 114           5.8          2.8           5.1          2.4
# 70            5.9          3.2           4.8          1.8
# 138           6.0          3.0           4.8          1.8
# 59            5.2          2.7           3.9          1.4
# 44            5.1          3.8           1.9          0.4
# 125           7.2          3.2           6.0          1.8
# 36            5.5          3.5           1.3          0.2
# 141           6.9          3.1           5.1          2.3
# 12            4.8          3.0           1.4          0.1
# 63            6.1          2.9           4.7          1.4
# 106           4.9          2.5           4.5          1.7
# 96            5.7          2.9           4.2          1.3
# 103           6.3          2.9           5.6          1.8
# 22            4.6          3.6           1.0          0.2
# 26            5.0          3.4           1.6          0.4
# ...

# %%
scores_data = pd.DataFrame()
from sklearn.model_selection import cross_val_score
max_depth_values = range(1,100)
np.random.seed(0)
for max_depth in max_depth_values:
    clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = max_depth)
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train,y_train)
    test_score = clf.score(X_test, y_test)
    mean_cross_val_score = cross_val_score(clf, X_train, y_train, cv = 5).mean()
    temp_score_data = pd.DataFrame({'max_depth' : [max_depth],
                                   'train_score' : [train_score],
                                   'test_score' : [test_score],
                                   'cross_val_score' : [mean_cross_val_score]})
    scores_data = scores_data.append(temp_score_data)

# %%
scores_data_long = pd.melt(scores_data, id_vars = ['max_depth'], 
                          value_vars = ['train_score', 'test_score', 'cross_val_score'],
                          var_name = 'set_type', value_name = 'score')

# %%
sns.set(rc = {'figure.figsize' : (9,6)})
sns.lineplot(x = 'max_depth', y = 'score', hue = 'set_type', data = scores_data_long)

# %%
scores_data_long.query('set_type == "cross_val_score"').sort_values('score', ascending = False)
# Out:
#      max_depth         set_type  score
# 247         50  cross_val_score   0.96
# 272         75  cross_val_score   0.96
# 270         73  cross_val_score   0.96
# 269         72  cross_val_score   0.96
# 268         71  cross_val_score   0.96
# ..         ...              ...    ...
# 227         30  cross_val_score   0.96
# 226         29  cross_val_score   0.96
# 201          4  cross_val_score   0.96
# 199          2  cross_val_score   0.95
# 198          1  cross_val_score   0.70
#
# [99 rows x 3 columns]

# %%
clf_f = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 50)

# %%
clf_f.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=50,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
graph = Source(tree.export_graphviz(
    clf_f, out_file = None,
    feature_names = list(X), class_names = ['0','1', '2'],
    filled = True))
display(SVG(graph.pipe(format = 'svg')))

# %%
cross_val_score(clf_f, X_test, y_test, cv = 5).mean()
# Out:
# 0.9399999999999998

# %%
cnt = 0
for i in y_test:
    if i == 0:
        cnt = cnt + 1
cnt
# Out:
# 15

# %%
test_score = clf_f.score(X_test, y_test)
test_score
# Out:
# 0.92
